# %%
# 1.Load the diabetes dataset into a Pandas DataFrame. 
import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

# %%
df=pd.read_csv('diabetes.csv')

# %%
# 2.Display the first 5 records.
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#3.Display the first ten records of the dataset.
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
# 4.	Display the last five records of the dataset.
df.tail(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
# 5.	Display the last ten records of the dataset.
df.tail(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# ...

# %%
# 6.	Display the number of rows and columns in the dataset.
df.shape
# Out:
# (768, 9)

# %%
# 7.	Display all column names.
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# 8.Display the data types of all columns.
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
# 9.Display complete information about the dataset.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#10.	Display the number of unique values in each column.
df.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
#11.	Display the unique values in the Outcome column.
df["Outcome"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
#12.	Count the number of patients in each Outcome category.
df["Outcome"].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
#13.	Identify the target variable.
target_variable = "Outcome"
print("target variable:",target_variable)
print()
# Out:
# target variable: Outcome

# %%
#14.	Separate the features and target variable.
x=df.drop('Outcome',axis=1)
y=df["Outcome"]

print("features: ",x)
print("\ntarget variable",y)
# Out:
# features:       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# ...

# %%
#15.	Generate a statistical summary of the dataset.
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#16.	Find the average value of each numerical column.
df.mean(numeric_only=True)
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
#17.	Find the median value of each numerical column.
df.median(numeric_only=True)
# Out:
# Pregnancies                   3.0000
# Glucose                     117.0000
# BloodPressure                72.0000
# SkinThickness                23.0000
# Insulin                      30.5000
# BMI                          32.0000
# DiabetesPedigreeFunction      0.3725
# Age                          29.0000
# Outcome                       0.0000
# dtype: float64

# %%
#18.Find the minimum value of each column.
print("minimum value:")
df.min()
# Out:
# minimum value:
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# dtype: float64

# %%
#19.	Find the maximum value of each column.
df.max()
# Out:
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# dtype: float64

# %%
#20.	Find the average glucose level of the patients.
avg_Glucose = df["Glucose"].mean()
print("Average Glucose: ",avg_Glucose)
# Out:
# Average Glucose:  120.89453125

# %%
#21.	Find the average BMI of the patients.
avg_BMI = df["BMI"].mean()
print("Average BMI: ",avg_BMI)
# Out:
# Average BMI:  31.992578124999977

# %%
#22.	Find the average age of the patients.
avg_Age = df["Age"].mean()
print("Average Age: ",avg_Age)
# Out:
# Average Age:  33.240885416666664

# %%
#23.	Find the maximum glucose level.
max_glucose = df["Glucose"].max()
print("Maximum Glucose: ",max_glucose)
# Out:
# Maximum Glucose:  199

# %%
#24.	Find the minimum glucose level.
min_glucose = df["Glucose"].max()
print("Minimum Glucose: ",min_glucose)
# Out:
# Minimum Glucose:  199

# %%
#25.Find the average glucose level for diabetic patients only.
df[df["Outcome"]==1]["Glucose"].mean()
# Out:
# 141.25746268656715

# %%
#26.Find the average glucose level for non-diabetic patients
df[df["Outcome"]==0]["Glucose"].mean()
# Out:
# 109.98

# %%
#27.Count the number of diabetic and non-diabetic patients.
outcome_counts = df["Outcome"].value_counts()
print("non-diabetic patients: ", outcome_counts.get(0))
print("diabetic patients: ", outcome_counts.get(1))
# Out:
# non-diabetic patients:  500
# diabetic patients:  268

# %%
#28.Calculate the percentage of diabetic and non-diabetic patients.
outcome_counts = df["Outcome"].value_counts(normalize=True)*100
print("non-diabetic patients: ", outcome_counts.get(0),"%")
print("diabetic patients: ", outcome_counts.get(1),"%")
# Out:
# non-diabetic patients:  65.10416666666666 %
# diabetic patients:  34.89583333333333 %

# %%
#29.Check whether the dataset contains null values.
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#30.Calculate the total number of null values in the dataset.
df.isnull().sum().sum()
# Out:
# 0

# %%
#31.Display only the columns that contain null values 
df.columns[df.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
#32.Find the percentage of missing values in each column
df.isnull().mean()*100
# Out:
# Pregnancies                 0.0
# Glucose                     0.0
# BloodPressure               0.0
# SkinThickness               0.0
# Insulin                     0.0
# BMI                         0.0
# DiabetesPedigreeFunction    0.0
# Age                         0.0
# Outcome                     0.0
# dtype: float64

# %%
#33.Check whether any null value exist anywhere in the dataset 
print("Any null values?")
print(df.isnull().values.any())
# Out:
# Any null values?
# False

# %%
#34.Count the number of zero values in each column 
print("Number of zero values in each column:")
print((df == 0).sum())
# Out:
# Number of zero values in each column:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %%
#35.Find the number of zero glucose valuesvel
print("Number of zero glucose values:")
print((df["Glucose"] == 0).sum())
# Out:
# Number of zero glucose values:
# 5

# %%
#36.identify columns where zero may represent missing or invalid data
zero_col=df.columns[(df==0).any()]
print(zero_col)
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'Outcome'],
#       dtype='object')

# %%
#37.Replace invalid zero values with NaN
df=df.replace(0,np.nan)
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      NaN  33.6
# 1          1.0     85.0           66.0           29.0      NaN  26.6
# 2          8.0    183.0           64.0            NaN      NaN  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          NaN    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50      1.0
# 1                     0.351   31      NaN
# 2                     0.672   32      1.0
# 3                     0.167   21      NaN
# 4                     2.288   33      1.0

# %%
#38.Check the missing values after replacing zeros with NaN
df.isnull().sum()
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %%
#39.Calculate the total number of missing values after replacing zeros.
df.isnull().sum().sum()
# Out:
# 1263

# %%
#40.calculate percentage of missing values after replacing zeros
df.isnull().mean()*100
# Out:
# Pregnancies                 14.453125
# Glucose                      0.651042
# BloodPressure                4.557292
# SkinThickness               29.557292
# Insulin                     48.697917
# BMI                          1.432292
# DiabetesPedigreeFunction     0.000000
# Age                          0.000000
# Outcome                     65.104167
# dtype: float64

# %%
#41.Remove all rows containing missing values.
df.dropna()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 6            3.0     78.0           50.0           32.0     88.0  31.0
# 8            2.0    197.0           70.0           45.0    543.0  30.5
# 13           1.0    189.0           60.0           23.0    846.0  30.1
# 14           5.0    166.0           72.0           19.0    175.0  25.8
# 19           1.0    115.0           70.0           30.0     96.0  34.6
# ..           ...      ...            ...            ...      ...   ...
# 730          3.0    130.0           78.0           23.0     79.0  28.4
# 732          2.0    174.0           88.0           37.0    120.0  44.5
# 740         11.0    120.0           80.0           37.0    150.0  42.3
# 748          3.0    187.0           70.0           22.0    200.0  36.4
# 755          1.0    128.0           88.0           39.0    110.0  36.5
#
#      DiabetesPedigreeFunction  Age  Outcome
# 6                       0.248   26      1.0
# ...

# %%
#42.Display the shape of the original dataset.
df.shape
# Out:
# (768, 9)

# %%
#43.Display the shape of the dataset after removing missing values.
df_no_missing.shape
# Out:
# (111, 9)

# %%
#44.Check whether any missing values remain after removing rows.

# %%
#45.Create a copy of the dataset before filling missing values.

# %%
#46.Fill missing values using the mean.

# %%
#47.Check the information of the cleaned dataset.

# %%
#48.Check whether the cleaned dataset contains any missing values.

# %%
#49.Display the statistical summary of the cleaned dataset.

# %%
#50.Perform the complete data-cleaning process from loading the dataset to filling missing values using the median.
